# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
df = pd.read_csv('LoanStats3b.csv', header=1, low_memory=False, skiprows=[19017])

# %%
df['issue_dt'] = pd.to_datetime(df.issue_d)
dfts = df.set_index('issue_dt')

# %%
year_month_summary = dfts.groupby(lambda x: x.year*100 + x.month).count()

# %%
year_month_summary.head(24)
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv   term  \
# 201201   2602       2602       2602         2602             2602   2602
# 201202   2560       2560       2560         2560             2560   2560
# 201203   2914       2914       2914         2914             2914   2914
# 201204   3230       3230       3230         3230             3230   3230
# 201205   3400       3400       3400         3400             3400   3400
# 201206   3817       3817       3817         3817             3817   3817
# 201207   4627       4627       4627         4627             4627   4627
# 201208   5419       5419       5419         5419             5419   5419
# 201209   6087       6087       6087         6087             6087   6087
# 201210   6263       6263       6263         6263             6263   6263
# 201211   6382       6382       6382         6382             6382   6382
# 201212   6066       6066       6066         6066             6066   6066
# ...

# %%
loan_count_summary = year_month_summary['issue_d']

# %%
loan_count_summary
# Out:
# 201201     2602
# 201202     2560
# 201203     2914
# 201204     3230
# 201205     3400
# 201206     3817
# 201207     4627
# 201208     5419
# 201209     6087
# 201210     6263
# 201211     6382
# 201212     6066
# 201301     6872
# 201302     7561
# 201303     8273
# 201304     9419
# 201305    10350
# 201306    10899
# 201307    11910
# 201308    12674
# 201309    12987
# 201310    14115
# 201311    14675
# 201312    15020
# Name: issue_d, dtype: int64

# %% [markdown]
# 1_ Plot the loan data (loan_count_summary in from the previous assignment). Is the series stationary? If not, what would you do to transform it into a stationary series?

# %%
loan_count_summary.plot.bar()

# %%
sm.graphics.tsa.plot_acf(loan_count_summary)

# %%
sm.graphics.tsa.plot_pacf(loan_count_summary)
